# %%
import json

# %%
with open('debt_sdkp_result.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

print(data)
# Out:
# [{'Car': 'А012ХУ125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А022ХУ125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А026ХВ125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А055ТО125', 'Date': '2025-07-22T15:12:21', 'Sum': 0}, {'Car': 'А068ХК125', 'Date': '2025-07-22T15:42:31', 'Sum': 0}, {'Car': 'А092ТО125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А110ТО125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А139ТО125', 'Date': '2025-07-22T13:47:02', 'Sum': 0}, {'Car': 'А194УО125', 'Date': '2025-07-22T13:00:26', 'Sum': 0}, {'Car': 'А199УО125', 'Date': '2025-07-22T13:07:55', 'Sum': 0}, {'Car': 'А221ТО125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А257ТО125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А345ТО125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А370ХУ125', 'Date': '2025-07-22T15:44:17', 'Sum': 0}, {'Car': 'А381ТО125', 'Date': '2025-07-22T15:42:31', 'Sum': 0}, {'Car': 'А413ТО125', 'Date': '2025-07-22T15:42:31', 
# ...

# %%
import json

with open('history_tskad_result.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
import pandas as pd

# %%
pd.DataFrame(data).Sum.unique()
# Out:
# array([0])

# %%
pd.DataFrame(data).Car.unique()
# Out:
# array(['А012ХУ125', 'А022ХУ125', 'А026ХВ125', 'А055ТО125', 'А068ХК125',
#        'А092ТО125', 'А110ТО125', 'А139ТО125', 'А194УО125', 'А199УО125',
#        'А221ТО125', 'А257ТО125', 'А345ТО125', 'А370ХУ125', 'А381ТО125',
#        'А413ТО125', 'А549УС125', 'А550УС125', 'А573УС125', 'А575УС125',
#        'А753ТО125', 'А781ТО125', 'А911УТ125', 'А939УТ125', 'А947УТ125',
#        'А948УТ125', 'В110ХВ125', 'В344ХВ125', 'В355МУ125', 'В428УО125',
#        'В474УО125', 'В545ХЕ125', 'В546УО125', 'В560УО125', 'В571УО125',
#        'В621ХС125', 'В629ХЕ125', 'В634ХУ125', 'В647ХЕ125', 'В659ХС125',
#        'В728ХЕ125', 'В751ХЕ125', 'В758ХЕ125', 'В760ХЕ125', 'В762ХЕ125',
#        'В766ХЕ125', 'В784ХЕ125', 'В793ХН125', 'В798ХН125', 'В834ХВ125',
#        'В863ХТ125', 'В949НУ125', 'В959МУ125', 'В976ХС125', 'В987ХТ125',
#        'В997ХТ125', 'Е057ХУ125', 'Е103ТО125', 'Е132ТО125', 'Е173ТВ125',
#        'Е235ХУ125', 'Е248ХН125', 'Е251ХН125', 'Е252ХН125', 'Е256ХС125',
# ...
